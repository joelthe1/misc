# %%
import matplotlib.pyplot as plt

# %%
FB1_16way1 = [68.23, 75.19, 78.20, 79.16, 80.82, 80.91, 81.30, 81.96, 81.84, 82.38, 82.14, 82.48, 82.65, 82.41, 83.26, 82.75, 82.86, 82.56, 82.80, 83.13, 82.60, 82.55, 82.22, 82.82, 82.30, 82.36, 82.75, 82.79, 82.73, 82.61, 82.63, 82.40, 82.64, 82.49, 83.11, 82.76, 82.74, 82.79, 82.48, 82.51, 82.68, 82.69, 82.81, 82.62, 82.64, 82.59, 82.19, 82.59, 82.47, 82.78]

FB1_16way12 = [68.39, 75.25, 78.24, 79.95, 80.78, 81.23, 81.75, 81.81, 82.16, 82.14, 82.72, 82.30, 82.52, 82.37, 82.86, 82.88, 82.70, 82.80, 81.85, 83.20, 82.60, 82.69, 82.62, 82.54, 82.99, 82.09, 82.72, 82.68, 82.42, 82.55, 82.58, 82.51, 82.59, 82.59, 82.73, 82.48, 82.60, 82.84, 82.19, 82.57, 82.94, 82.46, 82.56, 82.14, 81.52, 82.24, 82.63, 82.59, 82.97, 82.22]

FB1_32way13 = [53.76, 66.92, 71.57, 74.78, 76.06, 76.63, 76.82, 77.08, 77.26, 77.33, 77.83, 77.82, 78.41, 78.37, 78.49, 78.43, 78.18, 78.59, 78.12, 78.61, 78.11, 79.03, 78.90, 78.90, 78.75, 78.75, 79.11, 79.28, 78.83, 78.87, 78.35, 78.75, 78.66, 78.68, 78.88, 78.33, 79.33, 78.78, 79.66, 78.79, 79.20, 78.83, 78.86, 78.74, 79.01, 78.79, 78.82, 78.89, 78.90, 78.33]

FB1_all = [86.97, 88.22, 89.09, 89.38, 89.47, 89.68, 89.83, 89.85, 89.82, 90.02, 90.02, 90.16, 90.33, 90.14, 90.12, 90.22, 90.07, 90.39, 90.31, 90.39, 90.44, 90.38, 90.31, 90.46, 90.39, 90.28, 90.35, 90.17, 90.17, 90.25, 90.30, 90.51, 90.18, 90.20, 90.30, 90.20, 90.12, 90.03, 90.13, 90.09, 90.14, 90.28, 90.16, 90.34, 90.12, 90.03, 90.22, 90.26, 90.24, 90.04]

print(f'Max full data (with 219554 sentences) = {max(FB1_all)}')
print(f'Max 16 way split (part 1 with 1012 sentences) = {max(FB1_16way1)}')
print(f'Max 16 way split (part 12 with 1024 sentences) = {max(FB1_16way12)}')
print(f'Max 32 way split (part 13 with 508 sentences) = {max(FB1_32way13)}')

fig, ax = plt.subplots()

x = range(1, len(FB1_16way1)+1)

plt.plot(x, FB1_all)
plt.plot(x, FB1_16way1)
plt.plot(x, FB1_16way12)
plt.plot(x, FB1_32way13)

#ax.set_xticks(list(range(1, 12, 5))+list(range(15, len(FB1)+1, 5)))
ax.set_ylim([0, 100])

ax.set_xlabel(f'Epoch (total epochs={len(FB1_16way1)})')
ax.set_ylabel(f'F1')
ax.set_title('F1 scores (from CoNLL eval script) per epoch')

plt.show()
# Out:
# Max full data (with 219554 sentences) = 90.51
# Max 16 way split (part 1 with 1012 sentences) = 83.26
# Max 16 way split (part 12 with 1024 sentences) = 83.2
# Max 32 way split (part 13 with 508 sentences) = 79.66

# %%
import os
os.getcwd()
# Out:
# '/nas/home/joel/src/misc/metis/notebooks'
